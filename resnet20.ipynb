# %% [markdown]
# Deep Residual Learning for Image Recognition

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers

# %%
def Identity_shortcut(x,filters,strides = 1):
    shortcut = x
    x = layers.Conv2D(filters = filters, kernel_size = 3, strides = strides, padding = 'same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters = filters, kernel_size = 3, padding = 'same')(x)
    x = layers.BatchNormalization()(x)
    if strides != 1:
        shortcut = layers.MaxPool2D(pool_size = 2, strides=2)(shortcut)
        shortcut = tf.pad(shortcut, tf.constant([[0, 0,], [0, 0,], [0, 0,], [0, filters//2]]), "CONSTANT")
    x = layers.Add()([shortcut,x])
    x = layers.ReLU()(x)
    return x

def Projection_shortcut(x,filters):
    shortcut = x
    x = layers.Conv2D(filters = filters, kernel_size = 3, strides = 2, padding = 'same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters = filters, kernel_size = 3, padding = 'same')(x)
    x = layers.BatchNormalization()(x)
    
    shortcut = layers.Conv2D(filters = filters, kernel_size = 1, strides = 2, 
                            padding = 'same')(shortcut)
    shortcut = layers.BatchNormalization()(shortcut)
    
    x = layers.Add()([shortcut,x])
    x = layers.ReLU()(x)
    return x

def resnet_20():
    inputs = layers.Input(shape=(32,32,3))
    x = layers.Conv2D(filters = 16, kernel_size = 3,strides = 1,padding = 'same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    #x = layers.MaxPooling2d(pool_size = (3,3), strides = 2, padding = 'same')
    
    x = Identity_shortcut(x,16)
    x = Identity_shortcut(x,16)
    x = Identity_shortcut(x,16)
    
    x = Identity_shortcut(x,32,2)
    x = Identity_shortcut(x,32)
    x = Identity_shortcut(x,32)
    
    x = Identity_shortcut(x,64,2)
    x = Identity_shortcut(x,64)
    x = Identity_shortcut(x,64)
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Flatten()(x)
    outputs = layers.Dense(10, activation='softmax')(x)
    
    model = keras.Model(inputs=inputs,outputs=outputs)
    
    model.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',
        metrics=['accuracy'])
    
    return model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
import datetime
import os

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

model = resnet_20() # or create_plain_net()
model.summary()

timestr = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
name = 'cifar-10_res_net_20-'+timestr 

checkpoint_path = "checkpoints/"+name+"/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
os.system('mkdir {}'.format(checkpoint_dir))

# save model after each epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1
)
tensorboard_callback = TensorBoard(
    log_dir='tensorboard_logs/'+name,
    histogram_freq=1
)

model.fit(
    x=x_train,
    y=y_train,
    epochs=20,
    verbose=1,
    validation_data=(x_test, y_test),
    batch_size=128,
    callbacks=[cp_callback, tensorboard_callback]
)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 27s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 16)   448         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 32, 32, 16)   64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 32, 32, 16)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 16)   2320        re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 32, 32, 16)   64          conv2d_48[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 32, 32, 16)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 16)   2320        re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 32, 32, 16)   64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 16)   0           re_lu_44[0][0]
#                                                                  batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 32, 32, 16)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 16)   2320        re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 32, 32, 16)   64          conv2d_50[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 32, 32, 16)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 16)   2320        re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 32, 16)   64          conv2d_51[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 16)   0           re_lu_46[0][0]
#                                                                  batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 32, 32, 16)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 16)   2320        re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 32, 32, 16)   64          conv2d_52[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 32, 32, 16)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 16)   2320        re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 16)   64          conv2d_53[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 16)   0           re_lu_48[0][0]
#                                                                  batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 32, 32, 16)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 32)   4640        re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 16, 16, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 16, 16, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 16)   0           re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 32)   9248        re_lu_51[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad_3 (TFOpLambda) (None, 16, 16, 32)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 16, 16, 32)   128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 32)   0           tf.compat.v1.pad_3[0][0]
#                                                                  batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 16, 16, 32)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 32)   9248        re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 16, 16, 32)   128         conv2d_56[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 16, 16, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 16, 32)   9248        re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 16, 16, 32)   128         conv2d_57[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 32)   0           re_lu_52[0][0]
#                                                                  batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, 16, 16, 32)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 16, 16, 32)   9248        re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 16, 16, 32)   128         conv2d_58[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 16, 16, 32)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 16, 16, 32)   9248        re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 16, 16, 32)   128         conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 32)   0           re_lu_54[0][0]
#                                                                  batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 16, 16, 32)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 8, 8, 64)     18496       re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 8, 8, 64)     256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 32)     0           re_lu_56[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 8, 8, 64)     36928       re_lu_57[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.pad_4 (TFOpLambda) (None, 8, 8, 64)     0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 8, 8, 64)     256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 64)     0           tf.compat.v1.pad_4[0][0]
#                                                                  batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# re_lu_58 (ReLU)                 (None, 8, 8, 64)     0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 8, 8, 64)     36928       re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 8, 8, 64)     256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# re_lu_59 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 8, 8, 64)     36928       re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 8, 8, 64)     256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 64)     0           re_lu_58[0][0]
#                                                                  batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# re_lu_60 (ReLU)                 (None, 8, 8, 64)     0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 8, 8, 64)     36928       re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 8, 8, 64)     256         conv2d_64[0][0]
# __________________________________________________________________________________________________
# re_lu_61 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 8, 8, 64)     36928       re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 8, 8, 64)     256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 64)     0           re_lu_60[0][0]
#                                                                  batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# re_lu_62 (ReLU)                 (None, 8, 8, 64)     0           add_27[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           re_lu_62[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 271,786
# Trainable params: 270,410
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# Epoch 1/20
# 391/391 [==============================] - 293s 742ms/step - loss: 1.6217 - accuracy: 0.4260 - val_loss: 1.7203 - val_accuracy: 0.4745
#
# Epoch 00001: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0001.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0001.ckpt\assets
# Epoch 2/20
# 391/391 [==============================] - 284s 726ms/step - loss: 0.9443 - accuracy: 0.6642 - val_loss: 1.2758 - val_accuracy: 0.5534
#
# Epoch 00002: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0002.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0002.ckpt\assets
# Epoch 3/20
# 391/391 [==============================] - 285s 729ms/step - loss: 0.7329 - accuracy: 0.7451 - val_loss: 1.0390 - val_accuracy: 0.6497
#
# Epoch 00003: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0003.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0003.ckpt\assets
# Epoch 4/20
# 391/391 [==============================] - 297s 760ms/step - loss: 0.6106 - accuracy: 0.7849 - val_loss: 1.0948 - val_accuracy: 0.6433
#
# Epoch 00004: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0004.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0004.ckpt\assets
# Epoch 5/20
# 391/391 [==============================] - 310s 794ms/step - loss: 0.5261 - accuracy: 0.8157 - val_loss: 0.9196 - val_accuracy: 0.7012
#
# Epoch 00005: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0005.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0005.ckpt\assets
# Epoch 6/20
# 391/391 [==============================] - 326s 834ms/step - loss: 0.4434 - accuracy: 0.8461 - val_loss: 1.0006 - val_accuracy: 0.6806
#
# Epoch 00006: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0006.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0006.ckpt\assets
# Epoch 7/20
# 391/391 [==============================] - 330s 843ms/step - loss: 0.3975 - accuracy: 0.8618 - val_loss: 1.8596 - val_accuracy: 0.5577
#
# Epoch 00007: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0007.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0007.ckpt\assets
# Epoch 8/20
# 391/391 [==============================] - 326s 834ms/step - loss: 0.3376 - accuracy: 0.8839 - val_loss: 0.9317 - val_accuracy: 0.7048
#
# Epoch 00008: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0008.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0008.ckpt\assets
# Epoch 9/20
# 391/391 [==============================] - 323s 826ms/step - loss: 0.2901 - accuracy: 0.9001 - val_loss: 1.2793 - val_accuracy: 0.6838
#
# Epoch 00009: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0009.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0009.ckpt\assets
# Epoch 10/20
# 391/391 [==============================] - 299s 766ms/step - loss: 0.2483 - accuracy: 0.9146 - val_loss: 1.2248 - val_accuracy: 0.6979
#
# Epoch 00010: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0010.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0010.ckpt\assets
# Epoch 11/20
# 391/391 [==============================] - 322s 823ms/step - loss: 0.2072 - accuracy: 0.9296 - val_loss: 1.3035 - val_accuracy: 0.6764
#
# Epoch 00011: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0011.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0011.ckpt\assets
# Epoch 12/20
# 391/391 [==============================] - 328s 838ms/step - loss: 0.1804 - accuracy: 0.9379 - val_loss: 0.9720 - val_accuracy: 0.7408
#
# Epoch 00012: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0012.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0012.ckpt\assets
# Epoch 13/20
# 391/391 [==============================] - 306s 782ms/step - loss: 0.1596 - accuracy: 0.9460 - val_loss: 1.3149 - val_accuracy: 0.6672
#
# Epoch 00013: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0013.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0013.ckpt\assets
# Epoch 14/20
# 391/391 [==============================] - 312s 797ms/step - loss: 0.1355 - accuracy: 0.9543 - val_loss: 1.5418 - val_accuracy: 0.6629
#
# Epoch 00014: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0014.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0014.ckpt\assets
# Epoch 15/20
# 391/391 [==============================] - 328s 840ms/step - loss: 0.1216 - accuracy: 0.9582 - val_loss: 1.5375 - val_accuracy: 0.6744
#
# Epoch 00015: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0015.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0015.ckpt\assets
# Epoch 16/20
# 391/391 [==============================] - 320s 819ms/step - loss: 0.1000 - accuracy: 0.9676 - val_loss: 1.5347 - val_accuracy: 0.7030
#
# Epoch 00016: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0016.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0016.ckpt\assets
# Epoch 17/20
# 391/391 [==============================] - 319s 816ms/step - loss: 0.0917 - accuracy: 0.9679 - val_loss: 1.1444 - val_accuracy: 0.7323
#
# Epoch 00017: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0017.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0017.ckpt\assets
# Epoch 18/20
# 391/391 [==============================] - 329s 842ms/step - loss: 0.0963 - accuracy: 0.9648 - val_loss: 2.3209 - val_accuracy: 0.6016
#
# Epoch 00018: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0018.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0018.ckpt\assets
# Epoch 19/20
# 391/391 [==============================] - 305s 781ms/step - loss: 0.0851 - accuracy: 0.9706 - val_loss: 1.4074 - val_accuracy: 0.7157
#
# Epoch 00019: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0019.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0019.ckpt\assets
# Epoch 20/20
# 391/391 [==============================] - 325s 830ms/step - loss: 0.0679 - accuracy: 0.9774 - val_loss: 1.8585 - val_accuracy: 0.6994
#
# Epoch 00020: saving model to checkpoints/cifar-10_res_net_20-20210106-155324\cp-0020.ckpt
# INFO:tensorflow:Assets written to: checkpoints/cifar-10_res_net_20-20210106-155324\cp-0020.ckpt\assets

# %% [markdown]
# Total params가 271,786인데 논문에는 0.27M으로 약 270000이다. 재현이 잘 되었다.

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 15316.
